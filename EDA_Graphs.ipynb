# %%
# import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# import dataframe
df = pd.read_csv("people_data_complete.csv")

# %%
# Pull the total number of active employee vs inactive
counts = df['Status'].value_counts()

# print the counts
print(counts)
# Out:
# 0    3409
# 1     599
# Name: Status, dtype: int64

# %%
# The percentages of active vs inactive

df['Status'].value_counts(normalize = True)
# Out:
# 0    0.850549
# 1    0.149451
# Name: Status, dtype: float64

# %%
# The percentages of each performance rating

df['Performance Rating'].value_counts(normalize = True)
# Out:
# 3    0.625998
# 2    0.317615
# 4    0.056387
# Name: Performance Rating, dtype: float64

# %%
# The percentages of employees by gender

df['Gender'].value_counts(normalize = True)
# Out:
# 0    0.608034
# 1    0.390719
# 2    0.001248
# Name: Gender, dtype: float64

# %%
counts_status = df['Status'].value_counts()

# create a bar plot of the counts
counts_status.plot(kind='bar', color='mediumseagreen', width= .8, tick_label=['Current Employees (0)', 'Employees who have left (1)'])

# add x-axis and y-axis labels
plt.xlabel('Status', fontsize=14)
plt.ylabel('Counts', fontsize=14)

# add a title to the plot
plt.title('Employee Count by Status')

#save the figure
plt.savefig('status.jpg', dpi=300, bbox_inches='tight', transparent='true')

# show the plot
plt.show()

# %%
# Pull the total number of employees by positions
counts = df['Position'].value_counts()

# create a bar chart of the counts
counts.plot(kind='bar', color='steelblue', width= .9)

# add x-axis and y-axis labels
plt.xlabel('Position', fontsize=14)
plt.ylabel('Counts', fontsize=14)

# add a title to the plot
plt.title('Employee Count by Position')

#save the figure
plt.savefig('position.jpg', dpi=300, bbox_inches='tight', transparent='true')

# show the plot
plt.show()

# %%
# Pull the total number of employees by gender
counts = df['Gender'].value_counts()

# create a bar chart of the counts
counts.plot(kind='bar', color='mediumseagreen', width= .9)

# add x-axis and y-axis labels
plt.xlabel('Gender', fontsize=14)
plt.ylabel('Counts', fontsize=14)

# add a title to the plot
plt.title('Employee Count by Gender')

# save the figure
plt.savefig('gender.jpg', dpi=300, bbox_inches='tight', transparent='true')

# show the plot
plt.show()

# %%
# Pull the total number of employees by race
counts = df['Race'].value_counts()

# create a bar chart of the counts
counts.plot(kind='bar', color='steelblue', width= .9)

# add x-axis and y-axis labels
plt.xlabel('Race', fontsize=14)
plt.ylabel('Counts', fontsize=14)

# add a title to the plot
plt.title('Employee Count by Race')

# save the figure
plt.savefig('race.jpg', dpi=300, bbox_inches='tight', transparent='true')

# show the plot
plt.show()

# %%
# Pull the total number of employee Education
counts = df['Education'].value_counts()

# create a bar chart of the counts
counts.plot(kind='bar', color='mediumseagreen', width= .9)

# add x-axis and y-axis labels
plt.xlabel('Education', fontsize=14)
plt.ylabel('Counts', fontsize=14)

# add a title to the plot
plt.title('Employee Count by Education')

# Save the figure
plt.savefig('education.jpg', dpi=300, bbox_inches='tight', transparent='true')

# show the plot
plt.show()

# %%
# Pull the total number of employees by salary
counts = df['Salary'].value_counts()

# create a bar chart of the counts
counts.plot(kind='bar', color='steelblue', width= .9)

# add x-axis and y-axis labels
plt.xlabel('Salary', fontsize=14)
plt.ylabel('Counts', fontsize=14)

# add a title to the plot
plt.title('Employee Count by Salary Range')

#save the figure
plt.savefig('salary.jpg', dpi=300, bbox_inches='tight', transparent='true')

# show the plot
plt.show()

# %%
# Pull the total number of employee by Work Life Balance
counts = df['Work Life Balance'].value_counts()

# create a bar chart of the counts
counts.plot(kind='bar', color='mediumseagreen', width= .9)

# add x-axis and y-axis labels
plt.xlabel('Work Life Balance', fontsize=14)
plt.ylabel('Counts', fontsize=14)

# add a title to the plot
plt.title('Employee Count by Work Life Balance')

#save the figure
plt.savefig('worklife.jpg', dpi=300, bbox_inches='tight', transparent='true')

# show the plot
plt.show()

# %%
# Pull the total number of employee positions
counts = df['Performance Rating'].value_counts()

# create a bar chart of the counts
counts.plot(kind='bar', color='steelblue', width= .9)

# add x-axis and y-axis labels
plt.xlabel('Performance', fontsize=14)
plt.ylabel('Counts', fontsize=14)

# add a title to the plot
plt.title('Employee Performance')

#save the figure
plt.savefig('performance.jpg', dpi=300, bbox_inches='tight', transparent='true')

# show the plot
plt.show()
